# %% [markdown]
# # Gesture Recognition
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started. Once you have completed the code you can download the notebook for making a submission.

# %%
import numpy as np
import os
from imageio import imread
from skimage.transform import resize
import datetime
import os
from PIL import Image, ImageFilter, ImageEnhance
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
os.environ['PYTHONHASHSEED']="30"
np.random.seed(30)
import random as rn
rn.seed(30)
import tensorflow as tf
tf.random.set_seed(30)
from keras import backend as K

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %% [markdown]
# **data path: /home/datasets/Project_data**

# %%
# train and validatiaon data creator with ablation
# when ablation is 10, then 10 folders for each label will be selected.
def get_data(path, ablation=None):
    train_doc = np.random.permutation(open(path+'train.csv').readlines())
    val_doc = np.random.permutation(open(path+'val.csv').readlines())
    counts = np.zeros(5) # count for loading folders for 5 classes
    train_data = []
    val_data = []
    # when ablation is None pass full training and val data
    if ablation is not None:
        # iterating train doc
        for doc in train_doc:
            lable = int(doc.strip().split(';')[2])
            if counts[lable] < ablation:
                train_data.append(doc)
                counts[lable] += 1 
        counts = np.zeros(5)
        # iterating val doc
        for doc in val_doc:
            lable = int(doc.strip().split(';')[2])
            if counts[lable] < ablation:
                val_data.append(doc)
                counts[lable] += 1
    else:
        train_data, val_data = train_doc, val_doc
    return train_data, val_data

# %%
train_doc, val_doc = get_data('/datasets/Project_data/', ablation=None)
batch_size = 32 # experiment with the batch size
enable_augmentation = False # augmentation of Data
# sequence ids
# selecting alternate frames from 7 to 26.
seq_idx = range(7,26,2)
# image dimensions
dim_x, dim_y = 120, 120

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
# generator with augmentation for train data
def generator(source_path, folder_list, batch_size, is_train = False, augmention = False, debug=False):
    # print('\nSource path = ', source_path, '; batch size =', batch_size)
    img_idx = seq_idx #create a list of image numbers you want to use for a particular video
    x = len(img_idx)
    y, z = dim_x, dim_y
    while True:
        # doubling the data for augmentation
        if is_train and augmention:
            t = np.concatenate((np.random.permutation(folder_list), np.random.permutation(folder_list)))
        else:
            t = np.random.permutation(folder_list)
            
        if (len(t)%batch_size) == 0:
            num_batches = int(len(t)/batch_size)
        else:
            num_batches = len(t)//batch_size + 1
            
        for batch in range(num_batches): # we iterate over the number of batches
            batch_data = np.zeros((batch_size,x,y,z,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                if debug:
                    plt.figure(figsize=(20,5))
                #handling remaining datapoints
                folder_idx = folder + (batch*batch_size)
                if folder_idx >= len(t):
                    break
                folder_str = t[folder_idx]
                imgs = os.listdir(source_path+'/'+ folder_str.split(';')[0]) # read all the images in the folder
                # randomly enabling augmentation and augmentation type
                aug_type = None
                if is_train and augmention and rn.randint(0,1) == 1:
                    aug_type = rn.randint(0, 4) #randomly selecting augmentation type
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ folder_str.strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)

                    # plotting original images for debugging purpose only
                    if debug:
                        plt.subplot(2, x, idx+1)
                        plt.imshow(image.astype('uint8'))

                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    # making the rectangle images into square by cropping sides
                    # so the aspect ration can be mantained while resizing.
                    if image.shape[1] > image.shape[0]:
                        diff_px = image.shape[1] - image.shape[0]
                        crop_start = diff_px//2
                        crop_end = crop_start + image.shape[0]
                        image = image[:, crop_start:crop_end]
                    elif image.shape[0] > image.shape[1]:
                        diff_px = image.shape[0] - image.shape[1]
                        crop_start = diff_px//2
                        crop_end = crop_start + image.shape[1]
                        image = image[:, crop_start:crop_end]

                    resized_im = resize(image, (y,z), anti_aliasing=True)
                    #resize(image, (y, z), anti_aliasing=True)

                    if aug_type is not None:
                        if aug_type == 0: # edge Enhancement
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.EDGE_ENHANCE))
                        elif aug_type == 1: # adding gaussian blur
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.GaussianBlur(1)))
                        elif aug_type == 2: # enchancing image detailing
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.DETAIL))
                        elif aug_type == 3: # sharpening image
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.SHARPEN))
                        elif aug_type == 4: # Brightness enhancement
                            resized_im = np.array(ImageEnhance.Brightness((Image.fromarray(resized_im, 'RGB'))).enhance(1.5))
                    # plotting rezised images for debugging purpose only
                    if debug:
                        plt.subplot(2, x, idx+x+1)
                        plt.imshow(resized_im)

                    batch_data[folder,idx,:,:,0] = resized_im[:,:,0]/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = resized_im[:,:,1]/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = resized_im[:,:,2]/255 #normalise and feed in the image

                batch_labels[folder, int(folder_str.strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
train_path = '/datasets/Project_data/train' #'/notebooks/storage/Final_data/Collated_training/train'
val_path =  '/datasets/Project_data/val' #'/notebooks/storage/Final_data/Collated_training/val'

#multiply number train seq by 2 when using augmentation
multiplier = 1
if enable_augmentation:
    multiplier = 2
num_train_sequences = len(train_doc)*multiplier
print('# training sequences =', num_train_sequences)

num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)

num_epochs = 50 # choose the number of epochs
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 50

# %%
# testing generative 
test_gen = generator(train_path, train_doc, 1, is_train = True, augmention = True, debug = True)
d = next(test_gen)[0]

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
#from tensorflow.keras.models import Sequential
#from tensorflow.keras.layers import Dense, GRU, Dropout, Flatten, BatchNormalization, Activation, Conv3D, MaxPooling3D
#from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
#from tensorflow.keras import optimizers

from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Bidirectional, BatchNormalization, Activation, Dropout, GlobalAveragePooling2D, GlobalAveragePooling3D, ConvLSTM2D
from keras.layers.convolutional import Conv2D, Conv3D, MaxPooling2D, MaxPooling3D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers

#input shape for the st layer
input_shape = (len(seq_idx), dim_x, dim_y, 3)
np.random.seed(30)

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %% [markdown]
# ### Experiment - 1 & 2

# %% [markdown]
# Conv3D

# %%
# model = Sequential()
# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(MaxPooling3D(pool_size=2))

# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=2))

# model.add(Flatten())
# model.add(Dense(256, activation='relu'))
# model.add(Dense(5, activation='softmax'))
# Out:
# 2024-01-30 19:04:29.968959: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2024-01-30 19:04:29.969039: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14800 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:1b:00.0, compute capability: 7.5

# %% [markdown]
# ### Experiment 3 Conv3D

# %%
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))

# model.add(Conv3D(256, kernel_size=(3, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(3, 2, 2)))

# model.add(Conv3D(512, kernel_size=(3, 3, 3), activation='relu'))
# model.add(Conv3D(512, kernel_size=(3, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))

# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment 4 Conv3D

# %%
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))

# model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))

# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))

# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment 5, 6 Conv3D

# %%
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))
# model.add(BatchNormalization())

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())

# model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())

# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())

# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment 7, 8 Conv3D

# %%
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))
# model.add(BatchNormalization())
# #model.add(Dropout(0.2))
# model.add(Dropout(0.5))

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# #model.add(Dropout(0.2))
# model.add(Dropout(0.5))

# model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# #model.add(Dropout(0.2))
# model.add(Dropout(0.5))

# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# #model.add(Dropout(0.2))
# model.add(Dropout(0.5))

# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment 9 Conv3D

# %%
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment 10 Conv3D

# %%
# loss: 0.1388 - categorical_accuracy: 0.9539 - val_loss: 0.1661 - val_categorical_accuracy: 0.9297
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(GlobalAveragePooling3D())
# model.add(Dense(512, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 11
#
# TimeDistributed Conv2D + GRU

# %%
# model = Sequential()
# model.add(TimeDistributed(
#     Conv2D(32, (3,3), activation='relu'), input_shape=input_shape)
# )
# model.add(TimeDistributed(
#     MaxPooling2D((2,2)))
# )
# model.add(BatchNormalization())

# model.add(TimeDistributed(
#     Conv2D(64, (3,3), activation='relu'))
# )
# model.add(TimeDistributed(
#     MaxPooling2D((2,2)))
# )
# model.add(BatchNormalization())

# model.add(TimeDistributed(GlobalAveragePooling2D()))
# model.add(TimeDistributed(Dense(64, activation='relu')))
# model.add(BatchNormalization())

# model.add(GRU(128))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 12
#
# TimeDistributed Conv2D + GRU

# %%
# model = Sequential()
# model.add(TimeDistributed(
#     Conv2D(32, (3,3), activation='relu'), input_shape=input_shape)
# )
# model.add(TimeDistributed(
#     MaxPooling2D((2,2)))
# )
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(TimeDistributed(
#     Conv2D(64, (3,3), activation='relu'))
# )
# model.add(TimeDistributed(
#     MaxPooling2D((2,2)))
# )
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(TimeDistributed(GlobalAveragePooling2D()))
# model.add(TimeDistributed(Dense(64, activation='relu')))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(GRU(128))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 13
#
# TimeDistributed Conv2D + Dense

# %%
# model = Sequential()
# model.add(TimeDistributed(
#     Conv2D(32, (3,3), activation='relu'), input_shape=input_shape)
# )
# model.add(TimeDistributed(
#     MaxPooling2D((2,2)))
# )
# model.add(BatchNormalization())

# model.add(TimeDistributed(
#     Conv2D(64, (3,3), activation='relu'))
# )
# model.add(TimeDistributed(
#     MaxPooling2D((2,2)))
# )
# model.add(BatchNormalization())

# model.add(TimeDistributed(
#     Conv2D(128, (3,3), activation='relu'))
# )
# model.add(TimeDistributed(
#     MaxPooling2D((2,2)))
# )
# model.add(BatchNormalization())

# model.add(GlobalAveragePooling3D())
# model.add(Dense(256, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 14
#
# TimeDistributed + ConvLSTM2D

# %%
# model = Sequential()
# model.add(TimeDistributed(
#     Conv2D(8, (3,3), activation='relu'), input_shape=input_shape)
# )
# model.add(BatchNormalization())
# model.add(TimeDistributed(
#     Conv2D(16, (3,3), activation='relu'))
# )
# model.add(BatchNormalization())
# model.add(
#     ConvLSTM2D(8, kernel_size = 3, return_sequences=False)
# )
# model.add(BatchNormalization())
# model.add(TimeDistributed(
#     Dense(64, activation='relu'))
# )
# model.add(BatchNormalization())
# model.add(GlobalAveragePooling2D())
# model.add(Dense(64, activation='relu'))
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ## Final Model

# %%
model = Sequential()
model.add(TimeDistributed(
    Conv2D(8, (3,3), activation='relu'), input_shape=input_shape)
)
model.add(BatchNormalization())
model.add(TimeDistributed(
    Conv2D(16, (3,3), activation='relu'))
)
model.add(BatchNormalization())
model.add(
    ConvLSTM2D(8, kernel_size = 3, return_sequences=False)
)
model.add(BatchNormalization())
model.add(TimeDistributed(
    Dense(64, activation='relu'))
)
model.add(BatchNormalization())
model.add(GlobalAveragePooling2D())
model.add(Dense(64, activation='relu'))
model.add(Dense(5, activation='softmax'))

# %% [markdown]
# Since we've written the model, the next step is to compile the model. Printing the summary of the model, we can see the total number of parameters that need to be trained.

# %%
# optimiser = #write your optimizer
# model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
# print (model.summary())
from tensorflow import keras
optimiser = tf.keras.optimizers.Adam(lr=0.01) #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, 10, 118, 118, 8)  224
#  ibuted)
#
#  batch_normalization (BatchN  (None, 10, 118, 118, 8)  32
#  ormalization)
#
#  time_distributed_1 (TimeDis  (None, 10, 116, 116, 16)  1168
#  tributed)
#
#  batch_normalization_1 (Batc  (None, 10, 116, 116, 16)  64
#  hNormalization)
#
#  conv_lstm2d (ConvLSTM2D)    (None, 114, 114, 8)       6944
#
#  batch_normalization_2 (Batc  (None, 114, 114, 8)      32
#  hNormalization)
#
#  time_distributed_2 (TimeDis  (None, 114, 114, 64)     576
#  tributed)
#
#  batch_normalization_3 (Batc  (None, 114, 114, 64)     256
#  hNormalization)
#
#  global_average_pooling2d (G  (None, 64)               0
#  lobalAveragePooling2D)
#
#  dense_3 (Dense)             (None, 64)                4160
#
#  dense_4 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 13,781
# Trainable params: 13,589
# Non-trainable params: 192
# _________________________________________________________________
# None

# %% [markdown]
# Let us create the `train_generator` and the `val_generator` which will be used in `.fit_generator`.

# %%
train_generator = generator(train_path, train_doc, batch_size, is_train = True, augmention = enable_augmentation)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_name = 'model_init_exp_16' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'

if not os.path.exists(model_name):
    os.mkdir(model_name)

filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001, verbose=1) # write the REducelronplateau code here

callbacks_list = [checkpoint, LR]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit` method to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                        callbacks=callbacks_list, validation_data=val_generator, 
                        validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/50
# 2024-01-30 19:16:55.436338: I tensorflow/stream_executor/cuda/cuda_dnn.cc:377] Loaded cuDNN version 8302
# 21/21 [==============================] - ETA: 0s - loss: 1.4541 - categorical_accuracy: 0.3393
# Epoch 00001: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00001-1.45411-0.33929-1.82513-0.14062.h5
# 21/21 [==============================] - 64s 3s/step - loss: 1.4541 - categorical_accuracy: 0.3393 - val_loss: 1.8251 - val_categorical_accuracy: 0.1406 - lr: 0.0100
# Epoch 2/50
# 21/21 [==============================] - ETA: 0s - loss: 1.2042 - categorical_accuracy: 0.4301
# Epoch 00002: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00002-1.20422-0.43006-2.12167-0.17969.h5
# 21/21 [==============================] - 58s 3s/step - loss: 1.2042 - categorical_accuracy: 0.4301 - val_loss: 2.1217 - val_categorical_accuracy: 0.1797 - lr: 0.0100
# Epoch 3/50
# 21/21 [==============================] - ETA: 0s - loss: 1.0337 - categorical_accuracy: 0.5208
# Epoch 00003: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00003-1.03372-0.52083-2.24181-0.39844.h5
# 21/21 [==============================] - 58s 3s/step - loss: 1.0337 - categorical_accuracy: 0.5208 - val_loss: 2.2418 - val_categorical_accuracy: 0.3984 - lr: 0.0100
# Epoch 4/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9856 - categorical_accuracy: 0.5208
# Epoch 00004: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00004-0.98563-0.52083-1.65700-0.17969.h5
# 21/21 [==============================] - 57s 3s/step - loss: 0.9856 - categorical_accuracy: 0.5208 - val_loss: 1.6570 - val_categorical_accuracy: 0.1797 - lr: 0.0100
# Epoch 5/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9344 - categorical_accuracy: 0.5774
# Epoch 00005: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00005-0.93442-0.57738-1.40278-0.14844.h5
# 21/21 [==============================] - 55s 3s/step - loss: 0.9344 - categorical_accuracy: 0.5774 - val_loss: 1.4028 - val_categorical_accuracy: 0.1484 - lr: 0.0100
# Epoch 6/50
# 21/21 [==============================] - ETA: 0s - loss: 1.0019 - categorical_accuracy: 0.5432
# Epoch 00006: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00006-1.00192-0.54315-1.94384-0.18750.h5
# 21/21 [==============================] - 54s 3s/step - loss: 1.0019 - categorical_accuracy: 0.5432 - val_loss: 1.9438 - val_categorical_accuracy: 0.1875 - lr: 0.0100
# Epoch 7/50
# 21/21 [==============================] - ETA: 0s - loss: 1.3557 - categorical_accuracy: 0.4360
# Epoch 00007: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00007-1.35571-0.43601-2.45205-0.14062.h5
# 21/21 [==============================] - 59s 3s/step - loss: 1.3557 - categorical_accuracy: 0.4360 - val_loss: 2.4521 - val_categorical_accuracy: 0.1406 - lr: 0.0100
# Epoch 8/50
# 21/21 [==============================] - ETA: 0s - loss: 1.3235 - categorical_accuracy: 0.3557
# Epoch 00008: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00008-1.32354-0.35565-1.44394-0.15625.h5
# 21/21 [==============================] - 57s 3s/step - loss: 1.3235 - categorical_accuracy: 0.3557 - val_loss: 1.4439 - val_categorical_accuracy: 0.1562 - lr: 0.0100
# Epoch 9/50
# 21/21 [==============================] - ETA: 0s - loss: 1.3694 - categorical_accuracy: 0.3824
# Epoch 00009: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00009-1.36945-0.38244-2.55019-0.35938.h5
# 21/21 [==============================] - 58s 3s/step - loss: 1.3694 - categorical_accuracy: 0.3824 - val_loss: 2.5502 - val_categorical_accuracy: 0.3594 - lr: 0.0100
# Epoch 10/50
# 21/21 [==============================] - ETA: 0s - loss: 1.4487 - categorical_accuracy: 0.3795
# Epoch 00010: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00010-1.44867-0.37946-4.01562-0.39062.h5
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# 21/21 [==============================] - 59s 3s/step - loss: 1.4487 - categorical_accuracy: 0.3795 - val_loss: 4.0156 - val_categorical_accuracy: 0.3906 - lr: 0.0100
# Epoch 11/50
# 21/21 [==============================] - ETA: 0s - loss: 1.2031 - categorical_accuracy: 0.4211
# Epoch 00011: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00011-1.20310-0.42113-3.49183-0.16406.h5
# 21/21 [==============================] - 60s 3s/step - loss: 1.2031 - categorical_accuracy: 0.4211 - val_loss: 3.4918 - val_categorical_accuracy: 0.1641 - lr: 0.0020
# Epoch 12/50
# 21/21 [==============================] - ETA: 0s - loss: 1.1414 - categorical_accuracy: 0.4732
# Epoch 00012: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00012-1.14136-0.47321-2.28119-0.22656.h5
# 21/21 [==============================] - 52s 3s/step - loss: 1.1414 - categorical_accuracy: 0.4732 - val_loss: 2.2812 - val_categorical_accuracy: 0.2266 - lr: 0.0020
# Epoch 13/50
# 21/21 [==============================] - ETA: 0s - loss: 1.1090 - categorical_accuracy: 0.4628
# Epoch 00013: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00013-1.10902-0.46280-1.75932-0.42188.h5
# 21/21 [==============================] - 54s 3s/step - loss: 1.1090 - categorical_accuracy: 0.4628 - val_loss: 1.7593 - val_categorical_accuracy: 0.4219 - lr: 0.0020
# Epoch 14/50
# 21/21 [==============================] - ETA: 0s - loss: 1.1107 - categorical_accuracy: 0.4926
# Epoch 00014: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00014-1.11070-0.49256-1.62892-0.42188.h5
# 21/21 [==============================] - 54s 3s/step - loss: 1.1107 - categorical_accuracy: 0.4926 - val_loss: 1.6289 - val_categorical_accuracy: 0.4219 - lr: 0.0020
# Epoch 15/50
# 21/21 [==============================] - ETA: 0s - loss: 1.1658 - categorical_accuracy: 0.4628
# Epoch 00015: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00015-1.16576-0.46280-1.44329-0.39062.h5
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.001.
# 21/21 [==============================] - 53s 3s/step - loss: 1.1658 - categorical_accuracy: 0.4628 - val_loss: 1.4433 - val_categorical_accuracy: 0.3906 - lr: 0.0020
# Epoch 16/50
# 21/21 [==============================] - ETA: 0s - loss: 1.0609 - categorical_accuracy: 0.5060
# Epoch 00016: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00016-1.06094-0.50595-1.19125-0.25000.h5
# 21/21 [==============================] - 51s 3s/step - loss: 1.0609 - categorical_accuracy: 0.5060 - val_loss: 1.1913 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 17/50
# 21/21 [==============================] - ETA: 0s - loss: 1.0509 - categorical_accuracy: 0.5104
# Epoch 00017: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00017-1.05093-0.51042-1.17857-0.47656.h5
# 21/21 [==============================] - 54s 3s/step - loss: 1.0509 - categorical_accuracy: 0.5104 - val_loss: 1.1786 - val_categorical_accuracy: 0.4766 - lr: 0.0010
# Epoch 18/50
# 21/21 [==============================] - ETA: 0s - loss: 1.0551 - categorical_accuracy: 0.5134
# Epoch 00018: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00018-1.05507-0.51339-1.11645-0.32031.h5
# 21/21 [==============================] - 56s 3s/step - loss: 1.0551 - categorical_accuracy: 0.5134 - val_loss: 1.1165 - val_categorical_accuracy: 0.3203 - lr: 0.0010
# Epoch 19/50
# 21/21 [==============================] - ETA: 0s - loss: 1.0585 - categorical_accuracy: 0.5238
# Epoch 00019: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00019-1.05848-0.52381-1.09292-0.50781.h5
# 21/21 [==============================] - 58s 3s/step - loss: 1.0585 - categorical_accuracy: 0.5238 - val_loss: 1.0929 - val_categorical_accuracy: 0.5078 - lr: 0.0010
# Epoch 20/50
# 21/21 [==============================] - ETA: 0s - loss: 1.0442 - categorical_accuracy: 0.5223
# Epoch 00020: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00020-1.04422-0.52232-1.07268-0.52344.h5
# 21/21 [==============================] - 56s 3s/step - loss: 1.0442 - categorical_accuracy: 0.5223 - val_loss: 1.0727 - val_categorical_accuracy: 0.5234 - lr: 0.0010
# Epoch 21/50
# 21/21 [==============================] - ETA: 0s - loss: 1.0346 - categorical_accuracy: 0.5089
# Epoch 00021: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00021-1.03465-0.50893-1.05308-0.45312.h5
# 21/21 [==============================] - 59s 3s/step - loss: 1.0346 - categorical_accuracy: 0.5089 - val_loss: 1.0531 - val_categorical_accuracy: 0.4531 - lr: 0.0010
# Epoch 22/50
# 21/21 [==============================] - ETA: 0s - loss: 1.0106 - categorical_accuracy: 0.5372
# Epoch 00022: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00022-1.01061-0.53720-0.92145-0.37500.h5
# 21/21 [==============================] - 58s 3s/step - loss: 1.0106 - categorical_accuracy: 0.5372 - val_loss: 0.9215 - val_categorical_accuracy: 0.3750 - lr: 0.0010
# Epoch 23/50
# 21/21 [==============================] - ETA: 0s - loss: 1.0074 - categorical_accuracy: 0.5283
# Epoch 00023: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00023-1.00736-0.52827-0.92628-0.53906.h5
# 21/21 [==============================] - 57s 3s/step - loss: 1.0074 - categorical_accuracy: 0.5283 - val_loss: 0.9263 - val_categorical_accuracy: 0.5391 - lr: 0.0010
# Epoch 24/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9977 - categorical_accuracy: 0.5342
# Epoch 00024: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00024-0.99774-0.53423-0.94729-0.35938.h5
# 21/21 [==============================] - 56s 3s/step - loss: 0.9977 - categorical_accuracy: 0.5342 - val_loss: 0.9473 - val_categorical_accuracy: 0.3594 - lr: 0.0010
# Epoch 25/50
# 21/21 [==============================] - ETA: 0s - loss: 1.0143 - categorical_accuracy: 0.5089
# Epoch 00025: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00025-1.01431-0.50893-0.95095-0.56250.h5
# 21/21 [==============================] - 58s 3s/step - loss: 1.0143 - categorical_accuracy: 0.5089 - val_loss: 0.9510 - val_categorical_accuracy: 0.5625 - lr: 0.0010
# Epoch 26/50
# 21/21 [==============================] - ETA: 0s - loss: 1.0286 - categorical_accuracy: 0.5446
# Epoch 00026: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00026-1.02857-0.54464-0.92681-0.38281.h5
# 21/21 [==============================] - 59s 3s/step - loss: 1.0286 - categorical_accuracy: 0.5446 - val_loss: 0.9268 - val_categorical_accuracy: 0.3828 - lr: 0.0010
# Epoch 27/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9943 - categorical_accuracy: 0.5253
# Epoch 00027: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00027-0.99431-0.52530-0.83180-0.43750.h5
# 21/21 [==============================] - 58s 3s/step - loss: 0.9943 - categorical_accuracy: 0.5253 - val_loss: 0.8318 - val_categorical_accuracy: 0.4375 - lr: 0.0010
# Epoch 28/50
# 21/21 [==============================] - ETA: 0s - loss: 1.0120 - categorical_accuracy: 0.5432
# Epoch 00028: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00028-1.01205-0.54315-1.06106-0.51562.h5
# 21/21 [==============================] - 56s 3s/step - loss: 1.0120 - categorical_accuracy: 0.5432 - val_loss: 1.0611 - val_categorical_accuracy: 0.5156 - lr: 0.0010
# Epoch 29/50
# 21/21 [==============================] - ETA: 0s - loss: 1.0068 - categorical_accuracy: 0.5327
# Epoch 00029: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00029-1.00678-0.53274-0.92887-0.58594.h5
# 21/21 [==============================] - 59s 3s/step - loss: 1.0068 - categorical_accuracy: 0.5327 - val_loss: 0.9289 - val_categorical_accuracy: 0.5859 - lr: 0.0010
# Epoch 30/50
# 21/21 [==============================] - ETA: 0s - loss: 1.0019 - categorical_accuracy: 0.5491
# Epoch 00030: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00030-1.00190-0.54911-0.90329-0.41406.h5
# 21/21 [==============================] - 58s 3s/step - loss: 1.0019 - categorical_accuracy: 0.5491 - val_loss: 0.9033 - val_categorical_accuracy: 0.4141 - lr: 0.0010
# Epoch 31/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9774 - categorical_accuracy: 0.5208
# Epoch 00031: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00031-0.97743-0.52083-0.91064-0.60156.h5
# 21/21 [==============================] - 57s 3s/step - loss: 0.9774 - categorical_accuracy: 0.5208 - val_loss: 0.9106 - val_categorical_accuracy: 0.6016 - lr: 0.0010
# Epoch 32/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9705 - categorical_accuracy: 0.5491
# Epoch 00032: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00032-0.97052-0.54911-0.89594-0.39062.h5
# 21/21 [==============================] - 57s 3s/step - loss: 0.9705 - categorical_accuracy: 0.5491 - val_loss: 0.8959 - val_categorical_accuracy: 0.3906 - lr: 0.0010
# Epoch 33/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9531 - categorical_accuracy: 0.5446
# Epoch 00033: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00033-0.95315-0.54464-0.93030-0.58594.h5
# 21/21 [==============================] - 54s 3s/step - loss: 0.9531 - categorical_accuracy: 0.5446 - val_loss: 0.9303 - val_categorical_accuracy: 0.5859 - lr: 0.0010
# Epoch 34/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9914 - categorical_accuracy: 0.5461
# Epoch 00034: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00034-0.99142-0.54613-0.97093-0.60938.h5
# 21/21 [==============================] - 54s 3s/step - loss: 0.9914 - categorical_accuracy: 0.5461 - val_loss: 0.9709 - val_categorical_accuracy: 0.6094 - lr: 0.0010
# Epoch 35/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9390 - categorical_accuracy: 0.5506
# Epoch 00035: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00035-0.93901-0.55060-0.97416-0.35156.h5
# 21/21 [==============================] - 55s 3s/step - loss: 0.9390 - categorical_accuracy: 0.5506 - val_loss: 0.9742 - val_categorical_accuracy: 0.3516 - lr: 0.0010
# Epoch 36/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9395 - categorical_accuracy: 0.5670
# Epoch 00036: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00036-0.93947-0.56696-0.96207-0.35938.h5
# 21/21 [==============================] - 52s 3s/step - loss: 0.9395 - categorical_accuracy: 0.5670 - val_loss: 0.9621 - val_categorical_accuracy: 0.3594 - lr: 0.0010
# Epoch 37/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9336 - categorical_accuracy: 0.5789
# Epoch 00037: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00037-0.93358-0.57887-1.13234-0.29688.h5
# 21/21 [==============================] - 54s 3s/step - loss: 0.9336 - categorical_accuracy: 0.5789 - val_loss: 1.1323 - val_categorical_accuracy: 0.2969 - lr: 0.0010
# Epoch 38/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9336 - categorical_accuracy: 0.5759
# Epoch 00038: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00038-0.93358-0.57589-1.28200-0.46875.h5
# 21/21 [==============================] - 55s 3s/step - loss: 0.9336 - categorical_accuracy: 0.5759 - val_loss: 1.2820 - val_categorical_accuracy: 0.4688 - lr: 0.0010
# Epoch 39/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9798 - categorical_accuracy: 0.5387
# Epoch 00039: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00039-0.97982-0.53869-1.13907-0.50000.h5
# 21/21 [==============================] - 59s 3s/step - loss: 0.9798 - categorical_accuracy: 0.5387 - val_loss: 1.1391 - val_categorical_accuracy: 0.5000 - lr: 0.0010
# Epoch 40/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9218 - categorical_accuracy: 0.5699
# Epoch 00040: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00040-0.92181-0.56994-1.19323-0.45312.h5
# 21/21 [==============================] - 55s 3s/step - loss: 0.9218 - categorical_accuracy: 0.5699 - val_loss: 1.1932 - val_categorical_accuracy: 0.4531 - lr: 0.0010
# Epoch 41/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9442 - categorical_accuracy: 0.5536
# Epoch 00041: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00041-0.94423-0.55357-1.25933-0.27344.h5
# 21/21 [==============================] - 59s 3s/step - loss: 0.9442 - categorical_accuracy: 0.5536 - val_loss: 1.2593 - val_categorical_accuracy: 0.2734 - lr: 0.0010
# Epoch 42/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9795 - categorical_accuracy: 0.5565
# Epoch 00042: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00042-0.97948-0.55655-0.91228-0.37500.h5
# 21/21 [==============================] - 57s 3s/step - loss: 0.9795 - categorical_accuracy: 0.5565 - val_loss: 0.9123 - val_categorical_accuracy: 0.3750 - lr: 0.0010
# Epoch 43/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9816 - categorical_accuracy: 0.5446
# Epoch 00043: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00043-0.98160-0.54464-1.16221-0.30469.h5
# 21/21 [==============================] - 58s 3s/step - loss: 0.9816 - categorical_accuracy: 0.5446 - val_loss: 1.1622 - val_categorical_accuracy: 0.3047 - lr: 0.0010
# Epoch 44/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9559 - categorical_accuracy: 0.5699
# Epoch 00044: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00044-0.95586-0.56994-1.18017-0.26562.h5
# 21/21 [==============================] - 56s 3s/step - loss: 0.9559 - categorical_accuracy: 0.5699 - val_loss: 1.1802 - val_categorical_accuracy: 0.2656 - lr: 0.0010
# Epoch 45/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9793 - categorical_accuracy: 0.5699
# Epoch 00045: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00045-0.97934-0.56994-1.06253-0.54688.h5
# 21/21 [==============================] - 57s 3s/step - loss: 0.9793 - categorical_accuracy: 0.5699 - val_loss: 1.0625 - val_categorical_accuracy: 0.5469 - lr: 0.0010
# Epoch 46/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9386 - categorical_accuracy: 0.5625
# Epoch 00046: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00046-0.93861-0.56250-0.90693-0.42969.h5
# 21/21 [==============================] - 58s 3s/step - loss: 0.9386 - categorical_accuracy: 0.5625 - val_loss: 0.9069 - val_categorical_accuracy: 0.4297 - lr: 0.0010
# Epoch 47/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9442 - categorical_accuracy: 0.5595
# Epoch 00047: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00047-0.94419-0.55952-0.86224-0.43750.h5
# 21/21 [==============================] - 58s 3s/step - loss: 0.9442 - categorical_accuracy: 0.5595 - val_loss: 0.8622 - val_categorical_accuracy: 0.4375 - lr: 0.0010
# Epoch 48/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9353 - categorical_accuracy: 0.5580
# Epoch 00048: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00048-0.93525-0.55804-0.96416-0.35938.h5
# 21/21 [==============================] - 55s 3s/step - loss: 0.9353 - categorical_accuracy: 0.5580 - val_loss: 0.9642 - val_categorical_accuracy: 0.3594 - lr: 0.0010
# Epoch 49/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9505 - categorical_accuracy: 0.5491
# Epoch 00049: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00049-0.95051-0.54911-0.90716-0.63281.h5
# 21/21 [==============================] - 58s 3s/step - loss: 0.9505 - categorical_accuracy: 0.5491 - val_loss: 0.9072 - val_categorical_accuracy: 0.6328 - lr: 0.0010
# Epoch 50/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9225 - categorical_accuracy: 0.5967
# Epoch 00050: saving model to model_init_exp_16_2024-01-3019_01_33.810693/model-00050-0.92255-0.59673-1.04259-0.55469.h5
# 21/21 [==============================] - 58s 3s/step - loss: 0.9225 - categorical_accuracy: 0.5967 - val_loss: 1.0426 - val_categorical_accuracy: 0.5547 - lr: 0.0010

# %%
plt.figure(figsize=(20,6))
ax1 = plt.subplot(121)
ax1 = plt.plot(history.history['loss'])
ax1 = plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')
ax2 = plt.subplot(122)
ax2 = plt.plot(history.history['categorical_accuracy'])
ax2 = plt.plot(history.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('categorical_accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')
